# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
# importing datasets
#print(sns.get_dataset_names())  # all the datasets that are available 
df = sns.load_dataset("tips")    # load_dataset is used to load the dataset that is avialable in our sns
print(df)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.displot(df['tip'],kde=False)  # kde flag is set to false as a result the representation of kernal estimate plot will be removed and only histogram is plotted. 
plt.show()       # kernal density estimation - is the way to estimate the probability density function of continue random variable
#used for non parametric analysis

# %%
sns.displot(df['tip'],kind='hist')
plt.show()

# %%
sns.jointplot(x='tip',y='total_bill',data=df,kind='hex')
plt.show()
# hebinplot = hex
# 
#

# %%
sns.barplot(x='tip',y='total_bill',data=df)
plt.show()

# %%
sns.countplot(x='tip',data=df)
plt.show()

# %%
sns.pointplot(x='tip',y='total_bill',data=df)
plt.show()

# %% [markdown]
# cr=df[['total_bill','tip']].corr() # Correlation
# sns.heatmap(cr,annot=True,cmap='coolwarm')
# plt.show()

# %%
sns.pairplot(df,hue='sex')
plt.show()

# %%
sns.violinplot(x='day',y='total_bill',data=df)
plt.show()

# %%
#lineplot
sns.lineplot(x='total_bill',y='tip',data=df)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
#regplot
sns.regplot(x='tip',y='size',data=df)
# Out:
# <Axes: xlabel='tip', ylabel='size'>

# %%
#lmplot
sns.lmplot(x='total_bill',y='tip',data=df,hue='size')

# %%
#factor plot
sns.catplot(x='total_bill',y='smoker',data=df,kind='bar')

# %%
#catplot
sns.catplot(x='total_bill',y='tip',data=df,kind='box')

# %%
'''Seaborn Practical Assignment
Objective:
Use Seaborn to analyze and visualize a dataset effectively. You will generate different types of plots to explore relationships, distributions, and categorical data.

Dataset:
Use the built-in "penguins" dataset from Seaborn or any dataset of your choice.

Tasks:
1. Load Dataset
Import necessary libraries

Load the "penguins" dataset from Seaborn

Display basic information about the dataset (head, describe, info)

2. Univariate Analysis
Plot a histogram (sns.histplot) for a numerical column (e.g., body_mass_g)

Create a KDE plot (sns.kdeplot) for a numerical column

3. Bivariate Analysis
Scatter plot (sns.scatterplot) to analyze the relationship between flipper length and body mass

Line plot (sns.lineplot) if time-series data is available

Pairplot (sns.pairplot) to analyze relationships among multiple numerical columns

4. Categorical Data Visualization
Boxplot (sns.boxplot) to compare species and body mass

Countplot (sns.countplot) to see the distribution of species

Violin plot (sns.violinplot) to visualize category-wise distribution

5. Heatmap
Create a correlation heatmap (sns.heatmap) to check correlations between numerical columns

6. Customization
Customize color palettes

Adjust figure size and styles using sns.set()'''
# Out:
# 'Seaborn Practical Assignment\nObjective:\nUse Seaborn to analyze and visualize a dataset effectively. You will generate different types of plots to explore relationships, distributions, and categorical data.\n\nDataset:\nUse the built-in "penguins" dataset from Seaborn or any dataset of your choice.\n\nTasks:\n1. Load Dataset\nImport necessary libraries\n\nLoad the "penguins" dataset from Seaborn\n\nDisplay basic information about the dataset (head, describe, info)\n\n2. Univariate Analysis\nPlot a histogram (sns.histplot) for a numerical column (e.g., body_mass_g)\n\nCreate a KDE plot (sns.kdeplot) for a numerical column\n\n3. Bivariate Analysis\nScatter plot (sns.scatterplot) to analyze the relationship between flipper length and body mass\n\nLine plot (sns.lineplot) if time-series data is available\n\nPairplot (sns.pairplot) to analyze relationships among multiple numerical columns\n\n4. Categorical Data Visualization\nBoxplot (sns.boxplot) to compare species and body mass\n\nCou
# ...

# %%
import seaborn as sns
df=sns.load_dataset("penguins")
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.histplot('body_mass_g')
# Out:
# <Axes: ylabel='Count'>

# %%
sns.kdeplot(x='bill_depth_mm',y='body_mass_g',data=df)
# Out:
# <Axes: xlabel='bill_depth_mm', ylabel='body_mass_g'>

# %%
sns.scatterplot(x='bill_depth_mm',y='body_mass_g',data=df)
# Out:
# <Axes: xlabel='bill_depth_mm', ylabel='body_mass_g'>

# %%
sns.lineplot(x='body_mass_g',y='bill_depth_mm',data=df)
# Out:
# <Axes: xlabel='body_mass_g', ylabel='bill_depth_mm'>

# %%
sns.pairplot(df,hue='island')

# %%
sns.boxplot(x='bill_length_mm',y='body_mass_g',data=df) 
plt.show()

# %%
sns.violinplot(x='body_mass_g',y='bill_length_mm',data=df)
plt.show()

# %%
cr=df.corr(numeric_only=True)
sns.heatmap(cr,annot=True,cmap='coolwarm')
plt.show()

# %%
sns.palplot(sns.color_palette())
plt.show()

# %%
sns.set()
